# %% [markdown]
# # Project: Finding the Best Customers

# %% [markdown]
# In this project, I'll be using RFM, a customer segmentation technique that uses past purchase behavior that divide customers into groups in order to identify the top 10 customers.

# %% [markdown]
# ## I. Online Retail Data

# %%
import pandas as pd

data = pd.read_excel("Online Retail.xlsx")
data.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %% [markdown]
# The data contains all customers transactions that occured between December 1, 2010 - December 9, 2011 for a online retailed based in the UK

# %% [markdown]
# Here's what each columns represent:
# 1. <font color=red>InvoiceNo</font>: Unique ID for every time a customer visits the store.
# 2. <font color=red>StockCode</font>: Unique ID for a product
# 3. <font color=red>Description</font>: Description of the product
# 4. <font color=red>Quantity</font>: Quantity of units bought
# 5. <font color=red>InvoiceDate</font>: Date and time of purchase
# 6. <font color=red>Unit Price</font>: Price per unit
# 7. <font color=red>CustomerID</font>: Unique ID for each customer
# 8. <font color=red>Country</font>: Country where transaction happened

# %% [markdown]
# ## II. Exploring the Data

# %% [markdown]
# In this step, I'll be:
# 1. Explore if there are missing values
# 2. Explore the customers' distribution in each country
# 3. Invoice date should not be less or greater than the dates we specified
# 4. The unit price and quantity should be greater than 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# There are about 135,000 missing values in the CustomerID column, and since our analysis is based on customers, it's pointless to have transactions that we can't identify the customer

# %%
data = data[data["CustomerID"].notnull()]
data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# Now, there are no missing values in our data

# %%
data.shape
# Out:
# (406829, 8)

# %%
data = data[data["Quantity"]>0]
data.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %% [markdown]
# Now, we need to convert <font color=red>InvoiceDate</font> into datetime

# %%
data["InvoiceDate"] = pd.to_datetime(data["InvoiceDate"])
data.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
data["InvoiceDate"].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
data["InvoiceDate"].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %% [markdown]
# So, our data date ranges are correct.

# %% [markdown]
# Now, let's explore the customer distribution for each country

# %%
customer_country = data[["Country","CustomerID"]].drop_duplicates()
customer_country
# Out:
#                Country  CustomerID
# 0       United Kingdom     17850.0
# 9       United Kingdom     13047.0
# 26              France     12583.0
# 46      United Kingdom     13748.0
# 65      United Kingdom     15100.0
# 82      United Kingdom     15291.0
# 86      United Kingdom     14688.0
# 105     United Kingdom     17809.0
# 106     United Kingdom     15311.0
# 142     United Kingdom     16098.0
# 155     United Kingdom     18074.0
# 168     United Kingdom     17420.0
# 175     United Kingdom     16029.0
# 183     United Kingdom     16250.0
# 197          Australia     12431.0
# 211     United Kingdom     17511.0
# 242     United Kingdom     13705.0
# 252     United Kingdom     13747.0
# 253     United Kingdom     13408.0
# 264     United Kingdom     13767.0
# 296     United Kingdom     17924.0
# 298     United Kingdom     13448.0
# 318     United Kingdom     15862.0
# 382     United Kingdom     15513.0
# 385        Netherlands     12791.0
# 387     United Kingdom     16218.0
# 415     United Kingdom     14045.0
# 435     United Kingdom     14307.0
# 483     United Kingdom     17908.0
# 541     United Kingdom     17920.0
# ...                ...         ...
# 522968  United Kingdom     15773.0
# 523214  United Kingdom     17936.0
# 523945  United Kingdom     16535.0
# 524160  United Kingdom     16988.0
# 526348  United Kingdom     15097.0
# 526846  United Kingdom     18015.0
# 527022  United Kingdom     16597.0
# 527029  United Kingdom     13790.0
# 527305  United Kingdom     14219.0
# 527384         Denmark     12367.0
# 529479  United Kingdom     17383.0
# 529740          Greece     12478.0
# 530032  United Kingdom     15992.0
# 530144  United Kingdom     15318.0
# 530374  United Kingdom     17914.0
# 531020  United Kingdom     16528.0
# 531420           Spain     12442.0
# 531881  United Kingdom     16569.0
# 532691          France     12650.0
# 532735  United Kingdom     14578.0
# 533733  United Kingdom     16000.0
# 533812  United Kingdom     15195.0
# 533916  United Kingdom     14087.0
# 534247  United Kingdom     14204.0
# 534480  United Kingdom     15471.0
# 536969  United Kingdom     13436.0
# 537255  United Kingdom     15520.0
# 538064  United Kingdom     13298.0
# 538812  United Kingdom     14569.0
# 541768         Germany     12713.0
#
# [4347 rows x 2 columns]

# %% [markdown]
# From this table, we can tell that there are about 4347 unique customers.
#
# Let's group the table by country so we can determine the total number of unique customers each country has

# %%
customer_country.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID', ascending=False)
# Out:
#                  Country  CustomerID
# 35        United Kingdom        3921
# 14               Germany          94
# 13                France          87
# 30                 Spain          30
# 3                Belgium          25
# 32           Switzerland          21
# 26              Portugal          19
# 18                 Italy          14
# 12               Finland          12
# 1                Austria          11
# 24                Norway          10
# 23           Netherlands           9
# 0              Australia           9
# 9                Denmark           9
# 6        Channel Islands           9
# 7                 Cyprus           8
# 31                Sweden           8
# 19                 Japan           8
# 25                Poland           6
# 33                   USA           4
# 5                 Canada           4
# 36           Unspecified           4
# 15                Greece           4
# 10                  EIRE           3
# 17                Israel           3
# 22                 Malta           2
# 34  United Arab Emirates           2
# 2                Bahrain           2
# 8         Czech Republic           1
# 21             Lithuania           1
# 20               Lebanon           1
# 27                   RSA           1
# 28          Saudi Arabia           1
# 29             Singapore           1
# 16               Iceland           1
# 4                 Brazil           1
# 11    European Community           1

# %% [markdown]
# Most of our customers were based in the UK. Since customer clusters are different by geography, it's better to just focus on one market at this time. So let's choose the UK

# %%
data = data[data["Country"] == "United Kingdom"]
data.shape
# Out:
# (354345, 8)

# %% [markdown]
# ## III. RFM Customer Segmentation

# %% [markdown]
# Before we create our table, we need to identify which date to base our recency. Since our last invoice date was 2011-12-09, we can use 2011-12-10 to calculate it

# %%
import datetime 

now = datetime.datetime(2011,12,10)
now
# Out:
# datetime.datetime(2011, 12, 10, 0, 0)

# %% [markdown]
# Let's also add a new column for total price

# %%
data["TotalPrice"] = data["Quantity"] * data["UnitPrice"]
data.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00

# %% [markdown]
# Let's create our RFM Table

# %%
rfm = data.groupby('CustomerID').agg({'InvoiceDate': lambda x: (now - x.max()).days, 'InvoiceNo': lambda x: len(x), 'TotalPrice': lambda x: x.sum()})
rfm
# Out:
#             InvoiceDate  InvoiceNo  TotalPrice
# CustomerID
# 12346.0             325          1    77183.60
# 12747.0               2        103     4196.01
# 12748.0               0       4596    33719.73
# 12749.0               3        199     4090.88
# 12820.0               3         59      942.34
# 12821.0             214          6       92.72
# 12822.0              70         46      948.88
# 12823.0              74          5     1759.50
# 12824.0              59         25      397.12
# 12826.0               2         91     1474.72
# 12827.0               5         25      430.15
# 12828.0               2         56     1018.71
# 12829.0             336         11      293.00
# 12830.0              37         38     6814.64
# 12831.0             262          9      215.05
# 12832.0              32         27      383.03
# 12833.0             145         24      417.38
# 12834.0             282         18      312.38
# 12836.0              59        175     2612.86
# 12837.0             173         12      134.10
# 12838.0              33        123      683.13
# 12839.0               2        314     5591.42
# 12840.0             143        113     2726.77
# 12841.0               4        420     4022.35
# 12842.0              70         34     1118.99
# 12843.0              65        103     1702.26
# 12844.0              29         52      325.96
# 12845.0             267         27      354.09
# 12847.0              22         91      871.54
# 12849.0              31         51     1050.89
# ...                 ...        ...         ...
# 18242.0              72         78     2232.49
# 18245.0               7        175     2567.06
# 18246.0              23          4      596.10
# 18248.0             122         47      804.02
# 18249.0              17          8       95.34
# 18250.0             310         21      349.27
# 18251.0              87         16     4314.72
# 18252.0              50         98      526.67
# 18255.0              89          6      103.30
# 18257.0              39        118     2337.63
# 18259.0              24         42     2338.60
# 18260.0             172        134     2643.20
# 18261.0              43         21      324.24
# 18262.0             140         13      149.48
# 18263.0              25         61     1213.16
# 18265.0              72         46      801.51
# 18268.0             134          1       25.50
# 18269.0             366          7      168.60
# 18270.0              38         11      283.15
# 18272.0               2        166     3078.58
# 18273.0               2          3      204.00
# 18274.0              30         11      175.92
# 18276.0              43         14      335.86
# 18277.0              58          8      110.38
# 18278.0              73          9      173.90
# 18280.0             277         10      180.60
# 18281.0             180          7       80.82
# 18282.0               7         12      178.05
# 18283.0               3        756     2094.88
# 18287.0              42         70     1837.28
#
# [3921 rows x 3 columns]

# %%
rfm.dtypes
# Out:
# InvoiceDate      int64
# InvoiceNo        int64
# TotalPrice     float64
# dtype: object

# %%
rfm.rename(columns={
    'InvoiceDate': 'Recency',
    'InvoiceNo': "Frequency",
    'TotalPrice': "MonetaryValue"
}, inplace=True)
rfm
# Out:
#             Recency  Frequency  MonetaryValue
# CustomerID
# 12346.0         325          1       77183.60
# 12747.0           2        103        4196.01
# 12748.0           0       4596       33719.73
# 12749.0           3        199        4090.88
# 12820.0           3         59         942.34
# 12821.0         214          6          92.72
# 12822.0          70         46         948.88
# 12823.0          74          5        1759.50
# 12824.0          59         25         397.12
# 12826.0           2         91        1474.72
# 12827.0           5         25         430.15
# 12828.0           2         56        1018.71
# 12829.0         336         11         293.00
# 12830.0          37         38        6814.64
# 12831.0         262          9         215.05
# 12832.0          32         27         383.03
# 12833.0         145         24         417.38
# 12834.0         282         18         312.38
# 12836.0          59        175        2612.86
# 12837.0         173         12         134.10
# 12838.0          33        123         683.13
# 12839.0           2        314        5591.42
# 12840.0         143        113        2726.77
# 12841.0           4        420        4022.35
# 12842.0          70         34        1118.99
# 12843.0          65        103        1702.26
# 12844.0          29         52         325.96
# 12845.0         267         27         354.09
# 12847.0          22         91         871.54
# 12849.0          31         51        1050.89
# ...             ...        ...            ...
# 18242.0          72         78        2232.49
# 18245.0           7        175        2567.06
# 18246.0          23          4         596.10
# 18248.0         122         47         804.02
# 18249.0          17          8          95.34
# 18250.0         310         21         349.27
# 18251.0          87         16        4314.72
# 18252.0          50         98         526.67
# 18255.0          89          6         103.30
# 18257.0          39        118        2337.63
# 18259.0          24         42        2338.60
# 18260.0         172        134        2643.20
# 18261.0          43         21         324.24
# 18262.0         140         13         149.48
# 18263.0          25         61        1213.16
# 18265.0          72         46         801.51
# 18268.0         134          1          25.50
# 18269.0         366          7         168.60
# 18270.0          38         11         283.15
# 18272.0           2        166        3078.58
# 18273.0           2          3         204.00
# 18274.0          30         11         175.92
# 18276.0          43         14         335.86
# 18277.0          58          8         110.38
# 18278.0          73          9         173.90
# 18280.0         277         10         180.60
# 18281.0         180          7          80.82
# 18282.0           7         12         178.05
# 18283.0           3        756        2094.88
# 18287.0          42         70        1837.28
#
# [3921 rows x 3 columns]

# %% [markdown]
# ### Split the metrics

# %% [markdown]
# We need to split the table into segments. We can do this with quartiles

# %%
quantiles = rfm.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       Recency  Frequency  MonetaryValue
# 0.25     17.0       17.0         300.04
# 0.50     50.0       41.0         651.82
# 0.75    142.0       99.0        1575.89

# %%
quantiles = quantiles.to_dict()
quantiles
# Out:
# {'Frequency': {0.25: 17.0, 0.5: 41.0, 0.75: 99.0},
#  'MonetaryValue': {0.25: 300.03999999999996,
#   0.5: 651.82000000000016,
#   0.75: 1575.8900000000003},
#  'Recency': {0.25: 17.0, 0.5: 50.0, 0.75: 142.0}}

# %% [markdown]
# ### Creating a segmented RFM Table

# %% [markdown]
# The best customers are the ones with the:
# 1. Lowest recency
# 2. Highest frequency
# 3. High monetary amount

# %%
def calc_r(x,p,d):
    if x<= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4
    
def calc_f_m(x,p,d):
    if x<= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1
    
segment_rfm = rfm

segment_rfm["r_score"] = segment_rfm["Recency"].apply(calc_r, args=("Recency",quantiles))
segment_rfm["f_score"] = segment_rfm["Frequency"].apply(calc_f_m, args=("Frequency",quantiles))
segment_rfm["m_score"] = segment_rfm["MonetaryValue"].apply(calc_f_m, args=("MonetaryValue",quantiles))
segment_rfm.head(10)
# Out:
#             Recency  Frequency  MonetaryValue  r_score  f_score  m_score
# CustomerID
# 12346.0         325          1       77183.60        4        4        1
# 12747.0           2        103        4196.01        1        1        1
# 12748.0           0       4596       33719.73        1        1        1
# 12749.0           3        199        4090.88        1        1        1
# 12820.0           3         59         942.34        1        2        2
# 12821.0         214          6          92.72        4        4        4
# 12822.0          70         46         948.88        3        2        2
# 12823.0          74          5        1759.50        3        4        1
# 12824.0          59         25         397.12        3        3        3
# 12826.0           2         91        1474.72        1        2        2

# %% [markdown]
# Now, let's add a new column with the RFM score combined:

# %%
segment_rfm["RFMScore"] = segment_rfm["r_score"].astype(str)+ segment_rfm["f_score"].astype(str) + segment_rfm["m_score"].astype(str)
segment_rfm.head(10)
# Out:
#             Recency  Frequency  MonetaryValue  r_score  f_score  m_score  \
# CustomerID
# 12346.0         325          1       77183.60        4        4        1
# 12747.0           2        103        4196.01        1        1        1
# 12748.0           0       4596       33719.73        1        1        1
# 12749.0           3        199        4090.88        1        1        1
# 12820.0           3         59         942.34        1        2        2
# 12821.0         214          6          92.72        4        4        4
# 12822.0          70         46         948.88        3        2        2
# 12823.0          74          5        1759.50        3        4        1
# 12824.0          59         25         397.12        3        3        3
# 12826.0           2         91        1474.72        1        2        2
#
#            RFMScore
# CustomerID
# 12346.0         441
# 12747.0         111
# 12748.0         111
# 12749.0         111
# 12820.0         122
# 12821.0         444
# 12822.0         322
# 12823.0         341
# 12824.0         333
# 12826.0         122

# %%
segment_rfm.dtypes
# Out:
# Recency            int64
# Frequency          int64
# MonetaryValue    float64
# r_score            int64
# f_score            int64
# m_score            int64
# RFMScore          object
# dtype: object

# %% [markdown]
# ### Top 20 Customers

# %%
segment_rfm[segment_rfm["RFMScore"] =='111'].sort_values('MonetaryValue', ascending=False).head(20)
# Out:
#             Recency  Frequency  MonetaryValue  r_score  f_score  m_score  \
# CustomerID
# 18102.0           0        431      259657.30        1        1        1
# 17450.0           8        337      194550.79        1        1        1
# 17511.0           2        963       91062.38        1        1        1
# 16684.0           4        277       66653.56        1        1        1
# 14096.0           4       5111       65164.79        1        1        1
# 13694.0           3        568       65039.62        1        1        1
# 15311.0           0       2379       60767.90        1        1        1
# 13089.0           2       1818       58825.83        1        1        1
# 15769.0           7        130       56252.72        1        1        1
# 15061.0           3        403       54534.14        1        1        1
# 14298.0           8       1637       51527.30        1        1        1
# 14088.0          10        589       50491.81        1        1        1
# 17841.0           1       7847       40991.57        1        1        1
# 13798.0           1        349       37153.85        1        1        1
# 16013.0           3        139       37130.60        1        1        1
# 16422.0          17        369       34684.40        1        1        1
# 12748.0           0       4596       33719.73        1        1        1
# 15838.0          11        167       33643.08        1        1        1
# 17389.0           0        213       31833.68        1        1        1
# 13098.0           1        572       28882.44        1        1        1
#
#            RFMScore
# CustomerID
# 18102.0         111
# 17450.0         111
# 17511.0         111
# 16684.0         111
# 14096.0         111
# 13694.0         111
# 15311.0         111
# 13089.0         111
# 15769.0         111
# 15061.0         111
# 14298.0         111
# 14088.0         111
# 17841.0         111
# 13798.0         111
# 16013.0         111
# 16422.0         111
# 12748.0         111
# 15838.0         111
# 17389.0         111
# 13098.0         111
